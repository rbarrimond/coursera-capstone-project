# %% [markdown]
# # Rob's Capstone Project
#
# This notebook with contain my work for the [capstone project](https://www.coursera.org/learn/applied-data-science-capstone/home/welcome) for IBM Data Science Specialization certificate.
# ### Week 4
#
# **Name**: Robert Barrimond
#
# **Date**: May 15, 2021
#
# **REVIEWER PLEASE NOTE**
# I do _not_ comment my code with Markdown. As an SRE (Site Reliability Engineer), I do as application developers should do: document code _in the code_ and everywhere possible by the code itself. Having said that, SREs are also called to be data scientists as well. So, I use Markdown to "tell the story" as that first overview course taught me so many months ago. I hope this assignment was easy to follow and grade!
#
# ---
#
# ## Problem Statement
# I've decided to see if it's worth pursuing opening a Cambodian restaurant somewhere in Toronto. I noticed from the previous assignments that the city is quite cosmopolitan and would welcome such a restaurant. The real problem is _where_ to locate it. My strategy will be to narrow the list of venues to Asian restaurants, get premium data on just those venues, e.g. number of like and rating, and use that to produce better clusters that can make my decision easier.

# %%
#
# Import the necessary modules
#

# Data analysis and transformation
import pandas as pd
import numpy as np

# REST API access
import requests

# File access
import os
from os import path
import pickle

# Geocoders
import geopy
from geopy.geocoders import Nominatim

# Regex
import re

# %% [markdown]
# ## Retrieve and Clean Data for Analysis
# ### Build List of Asian Restaurants using the Foursquare API
#
# Because it took [some work](https://github.com/rbarrimond/Coursera_Capstone/blob/5afe9c180839529c96ee71c8a5fae69746b9f4c3/toronto-kmeans-clustering.ipynb) to build a clean dataframe of FSAs from Wikipedia, I'll omit that work here and simple read the pickle from disk. Next I use the Foursquare API `explore` endpoint to get all the nearby venues. Then I'll explore the clean dataframe of Toronto venues to see I know that the classifications from the Week 4 assignment were too broad. My first task is to see if I can narrow down the venues to Asian restaurants from a list of almost 270 categories. I guessed that categories ending in 'restaurant', 'joint', and 'place' would be enough to cover it. I managed to find 145 Asian restaurants.

# %%
# Load the FSA data from previous work
fsa_df = pd.read_pickle('fsa_df.pkl')
fsa_df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
# FourSquare credentials
CLIENT_ID = '0II4MXQK5GVKQA3YIZRXT3D0KWBAKEH2BCCYRWIK4H0DS5XH' # your Foursquare ID
CLIENT_SECRET = 'ZBOCOGUCP2AXOQNAFSPX05IAXWAPBNUBC2FTAGYJV4DDS3AA' # your Foursquare Secret
ACCESS_TOKEN = 'ESEQDUIWNVRAS11OKDDXMICGNUPXLZCHPVHCZ53OTT2LQWBS' # your FourSquare Access Token
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
# This function takes a sequence of names, lats and longs and produces a dataframe of nearby venues
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name'] ) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue ID',
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Retrieve all the venues in Toronto
toronto_venues = getNearbyVenues(fsa_df['PostalCode'], fsa_df['Latitude'], fsa_df['Longitude'])
toronto_venues.head(10)
# Out:
# M3A
# M4A
# M5A
# M6A
# M7A
# M9A
# M1B
# M3B
# M4B
# M5B
# M6B
# M9B
# M1C
# M3C
# M4C
# M5C
# M6C
# M9C
# M1E
# M4E
# M5E
# M6E
# M1G
# M4G
# M5G
# M6G
# M1H
# M2H
# M3H
# M4H
# M5H
# M6H
# M1J
# M2J
# M3J
# M4J
# M5J
# M6J
# M1K
# M2K
# M3K
# M4K
# M5K
# M6K
# M1L
# M2L
# M3L
# M4L
# M5L
# M6L
# M9L
# M1M
# M2M
# M3M
# M4M
# M5M
# M6M
# M9M
# M1N
# M2N
# M3N
# M4N
# M5N
# M6N
# M9N
# M1P
# M2P
# M4P
# M5P
# M6P
# M9P
# M1R
# M2R
# M4R
# M5R
# M6R
# M7R
# M9R
# M1S
# M4S
# M5S
# M6S
# M1T
# M4T
# M5T
# M1V
# M4V
# M5V
# M8V
# M9V
# M1W
# M4W
# M5W
# M8W
# M9W
# M1X
# M4X
# M5X
# M8X
# M4Y
# M7Y
# M8Y
# M8Z
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0          M3A              43.753259              -79.329656
# 1          M3A              43.753259              -79.329656
# 2          M4A              43.725882              -79.315572
# 3          M4A              43.725882              -79.315572
# 4          M4A              43.725882              -79.315572
# 5          M4A              43.725882              -79.315572
# 6          M4A              43.725882              -79.315572
# 7          M5A              43.654260              -79.360636
# 8          M5A              43.654260              -79.360636
# 9          M5A              43.654260              -79.360636
#
#                                        Venue                  Venue ID  \
# 0                            Brookbanks Park  4e8d9dcdd5fbbbb6b3003c7b
# 1                              Variety Store  4cb11e2075ebb60cd1c4caad
# 2                     Victoria Village Arena  4c633acb86b6be9a61268e34
# 3                                  Portugril  4f3ecce6e4b0587016b6f30d
# 4                                Tim Hortons  4bbe904a85fbb713420d7167
# 5  Eglinton Ave E & Sloane Ave/Bermondsey Rd  51e594d5498e07837484f577
# 6                                 Pizza Nova  4b8fe578f964a520106833e3
# 7                           Roselle Desserts  54ea41ad498e9a11e9e13308
# 8                              Tandem Coffee  53b8466a498e83df908c3f21
# 9                     Cooper Koo Family YMCA  574c229e498ebb5c6b257902
#
#    Venue Latitude  Venue Longitude         Venue Category
# 0       43.751976       -79.332140                   Park
# 1       43.751974       -79.333114      Food & Drink Shop
# 2       43.723481       -79.315635           Hockey Arena
# 3       43.725819       -79.312785  Portuguese Restaurant
# 4       43.725517       -79.313103            Coffee Shop
# 5       43.726086       -79.313620           Intersection
# 6       43.725824       -79.312860            Pizza Place
# 7       43.653447       -79.362017                 Bakery
# 8       43.653559       -79.361809            Coffee Shop
# 9       43.653249       -79.358008    Distribution Center

# %%
# Explore the types of restaurants
restaurants = toronto_venues.loc[ toronto_venues['Venue Category'].str.contains('restaurant', case=False, regex=True) ].copy()
types = restaurants['Venue Category'].str.replace("Restaurant", "")
types = pd.Series(types.unique())
types = types.sort_values().reset_index(drop=True)
types
# Out:
# 0
# 1                 American
# 2                    Asian
# 3                  Belgian
# 4                Brazilian
# 5           Cajun / Creole
# 6                Caribbean
# 7                  Chinese
# 8                Colombian
# 9             Comfort Food
# 10                   Cuban
# 11                 Dim Sum
# 12                   Doner
# 13                Dumpling
# 14        Eastern European
# 15               Ethiopian
# 16                 Falafel
# 17               Fast Food
# 18                Filipino
# 19                  French
# 20                  German
# 21             Gluten-free
# 22                   Greek
# 23                   Hakka
# 24                  Indian
# 25                 Italian
# 26                Japanese
# 27                  Korean
# 28              Korean BBQ
# 29          Latin American
# 30           Mediterranean
# 31                 Mexican
# 32          Middle Eastern
# 33         Modern European
# 34    Molecular Gastronomy
# 35                Moroccan
# 36            New American
# 37              Portuguese
# 38                   Ramen
# 39                 Seafood
# 40                   Sushi
# 41               Taiwanese
# 42                    Thai
# 43                   Theme
# 44                 Tibetan
# 45      Vegetarian / Vegan
# 46              Vietnamese
# dtype: object

# %%
# Explore the types of joints
joints = toronto_venues.loc[ toronto_venues['Venue Category'].str.contains('joint', case=False) ]
types = joints['Venue Category'].str.replace("Joint", "")
types = pd.Series(types.unique())
types = types.sort_values().reset_index(drop=True)
types
# Out:
# 0              BBQ
# 1           Burger
# 2    Fried Chicken
# 3            Wings
# dtype: object

# %%
# Explore the types of places
places = toronto_venues.loc[ toronto_venues['Venue Category'].str.contains('place', case=False) ]
types = places['Venue Category'].str.replace("Place", "")
types = pd.Series(types.unique())
types = types.sort_values().reset_index(drop=True)
types
# Out:
# 0     Burrito
# 1       Pizza
# 2        Poke
# 3     Poutine
# 4       Salad
# 5    Sandwich
# 6       Snack
# 7        Soup
# 8        Taco
# dtype: object

# %%
# Check the bars just to be sure I'm not missing anything Asian themed
bars = toronto_venues.loc[ toronto_venues['Venue Category'].str.contains('bar$', case=False, regex=True) ]
types = bars['Venue Category'].str.replace("Bar$", "", regex=True)
types = pd.Series(types.unique())
types = types.sort_values().reset_index(drop=True)
types
# Out:
# 0
# 1        Beer
# 2    Cocktail
# 3         Gay
# 4      Hookah
# 5       Hotel
# 6       Juice
# 7        Sake
# 8      Sports
# 9        Wine
# dtype: object

# %%
# Set the Asian categories based on the above and create a cleaned Asian restaurants dataframe
asian_categories = [ 'Asian', 'Chinese', 'Dim Sum', 'Dumpling', 'Filipino', 'Japanese', 'Korean', 'Korean BBQ', 'Ramen', 'Sushi', 'Taiwanese', 'Thai', 'Vietnamese']
asian_restaurants = toronto_venues.loc[ toronto_venues['Venue Category'].str.contains("|".join(asian_categories) + ' restaurant', case=False, regex=True) ].copy()
asian_restaurants.reset_index(drop=True, inplace=True)
asian_restaurants
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0            M5A              43.654260              -79.360636
# 1            M6A              43.718518              -79.464763
# 2            M7A              43.662301              -79.389494
# 3            M7A              43.662301              -79.389494
# 4            M7A              43.662301              -79.389494
# ..           ...                    ...                     ...
# 140          M4Y              43.665860              -79.383160
# 141          M4Y              43.665860              -79.383160
# 142          M4Y              43.665860              -79.383160
# 143          M4Y              43.665860              -79.383160
# 144          M4Y              43.665860              -79.383160
#
#                               Venue                  Venue ID  Venue Latitude  \
# 0                             Izumi  50e88fc6e4b007fcbb57aae8       43.649970
# 1    Lac Vien Vietnamese Restaurant  4ccc5aebee23a14370591ea8       43.721259
# 2                       Tokyo Sushi  4afca145f964a5208e2422e3       43.665885
# 3                      Sushi Garden  4ba6b463f964a520416a39e3       43.664858
# 4                       Tokyo Grill  4ad4c061f964a520abf720e3       43.665085
# ..                              ...                       ...             ...
# 140                   Tokyo Kitchen  4ae787b9f964a52020ac21e3       43.668783
# 141                   Onnki Donburi  59c54d4f2d2fd97564d4cfc8       43.669757
# 142                      Miss Korea  527428a5498e8e23580dbe15       43.668950
# 143                  Kokoni Izakaya  4c531b60a724e21e029e3af4       43.664181
# 144                     Asahi Sushi  4af0b965f964a52094de21e3       43.669874
#
#      Venue Longitude         Venue Category
# 0         -79.360153       Asian Restaurant
# 1         -79.468472  Vietnamese Restaurant
# 2         -79.386977       Sushi Restaurant
# 3         -79.384941       Sushi Restaurant
# 4         -79.384707    Japanese Restaurant
# ..               ...                    ...
# 140       -79.385153    Japanese Restaurant
# 141       -79.384574    Japanese Restaurant
# 142       -79.386165      Korean Restaurant
# 143       -79.380258    Japanese Restaurant
# 144       -79.382943       Sushi Restaurant
#
# [145 rows x 8 columns]

# %% [markdown]
# ### Pull Full Data from Foursquare for Each Asian Restaurant
# NOTE: The `/venue` endpoint is a premium API. As a result, I cached results to file.

# %%
# Read in venue data either from cache or from Foursquare
asian_venue_data = {}
if path.exists('asian_venue_data.pkl'):
    with open('asian_venue_data.pkl', 'rb') as f:
        asian_venue_data = pickle.load(f)
else:
    for venue_id in asian_restaurants['Venue ID']:
        url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(
            venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
        r = requests.get(url)
        if r.status_code == 200:
            asian_venue_data[venue_id] = r.json()['response']
            print('Read', asian_venue_data[venue_id]['venue']['name'])
        else:
            print('Unable to retrieve data for ID:', venue_id)
    with open('asian_venue_data.pkl', 'wb') as f:
        pickle.dump(asian_venue_data, f, pickle.HIGHEST_PROTOCOL)
print("Pulled data for", len(asian_venue_data), "venues.")
# Out:
# Pulled data for 119 venues.

# %%
# Create a dataframe for the venue data
asian_venue_data_df = pd.DataFrame()
for id in asian_venue_data:
    asian_venue_data_df = asian_venue_data_df.append(pd.json_normalize(asian_venue_data[id]), ignore_index=True)
asian_venue_data_df.set_index('venue.id', inplace=True)
asian_venue_data_df
# Out:
#                                               venue.name  venue.location.lat  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                           Izumi           43.649970
# 4ccc5aebee23a14370591ea8  Lac Vien Vietnamese Restaurant           43.721259
# 4afca145f964a5208e2422e3                     Tokyo Sushi           43.665885
# 4ba6b463f964a520416a39e3                    Sushi Garden           43.664858
# 4ad4c061f964a520abf720e3                     Tokyo Grill           43.665085
# ...                                                  ...                 ...
# 4ae787b9f964a52020ac21e3                   Tokyo Kitchen           43.668783
# 59c54d4f2d2fd97564d4cfc8                   Onnki Donburi           43.669757
# 527428a5498e8e23580dbe15                      Miss Korea           43.668950
# 4c531b60a724e21e029e3af4                  Kokoni Izakaya           43.664181
# 4af0b965f964a52094de21e3                     Asahi Sushi           43.669874
#
#                           venue.location.lng  \
# venue.id
# 50e88fc6e4b007fcbb57aae8          -79.360153
# 4ccc5aebee23a14370591ea8          -79.468472
# 4afca145f964a5208e2422e3          -79.386977
# 4ba6b463f964a520416a39e3          -79.384941
# 4ad4c061f964a520abf720e3          -79.384707
# ...                                      ...
# 4ae787b9f964a52020ac21e3          -79.385153
# 59c54d4f2d2fd97564d4cfc8          -79.384574
# 527428a5498e8e23580dbe15          -79.386165
# 4c531b60a724e21e029e3af4          -79.380258
# 4af0b965f964a52094de21e3          -79.382943
#
#                                               venue.location.labeledLatLngs  \
# venue.id
# 50e88fc6e4b007fcbb57aae8  [{'label': 'display', 'lat': 43.6499697935016,...
# 4ccc5aebee23a14370591ea8  [{'label': 'display', 'lat': 43.72125878799614...
# 4afca145f964a5208e2422e3  [{'label': 'display', 'lat': 43.66588533093684...
# 4ba6b463f964a520416a39e3  [{'label': 'display', 'lat': 43.66485840073255...
# 4ad4c061f964a520abf720e3  [{'label': 'display', 'lat': 43.66508523814939...
# ...                                                                     ...
# 4ae787b9f964a52020ac21e3  [{'label': 'display', 'lat': 43.66878262373862...
# 59c54d4f2d2fd97564d4cfc8  [{'label': 'display', 'lat': 43.66975742655123...
# 527428a5498e8e23580dbe15  [{'label': 'display', 'lat': 43.66894989012164...
# 4c531b60a724e21e029e3af4  [{'label': 'display', 'lat': 43.66418143381715...
# 4af0b965f964a52094de21e3  [{'label': 'display', 'lat': 43.66987385309732...
#
#                          venue.location.cc venue.location.city  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                CA             Toronto
# 4ccc5aebee23a14370591ea8                CA             Toronto
# 4afca145f964a5208e2422e3                CA             Toronto
# 4ba6b463f964a520416a39e3                CA             Toronto
# 4ad4c061f964a520abf720e3                CA             Toronto
# ...                                    ...                 ...
# 4ae787b9f964a52020ac21e3                CA             Toronto
# 59c54d4f2d2fd97564d4cfc8                CA             Toronto
# 527428a5498e8e23580dbe15                CA             Toronto
# 4c531b60a724e21e029e3af4                CA             Toronto
# 4af0b965f964a52094de21e3                CA             Toronto
#
#                          venue.location.state venue.location.country  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                   ON                 Canada
# 4ccc5aebee23a14370591ea8                   ON                 Canada
# 4afca145f964a5208e2422e3                   ON                 Canada
# 4ba6b463f964a520416a39e3                   ON                 Canada
# 4ad4c061f964a520abf720e3                   ON                 Canada
# ...                                       ...                    ...
# 4ae787b9f964a52020ac21e3                   ON                 Canada
# 59c54d4f2d2fd97564d4cfc8                   ON                 Canada
# 527428a5498e8e23580dbe15                   ON                 Canada
# 4c531b60a724e21e029e3af4                   ON                 Canada
# 4af0b965f964a52094de21e3                   ON                 Canada
#
#                                             venue.location.formattedAddress  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                               [Toronto ON, Canada]
# 4ccc5aebee23a14370591ea8           [141 Cartwright Ave, Toronto ON, Canada]
# 4afca145f964a5208e2422e3  [33 St. Joseph St. (Yonge and Wellesley), Toro...
# 4ba6b463f964a520416a39e3  [3 Wellesley St W (at Yonge), Toronto ON, Canada]
# 4ad4c061f964a520abf720e3  [582 Yonge St (at Wellesley St W), Toronto ON ...
# ...                                                                     ...
# 4ae787b9f964a52020ac21e3   [Charles St. (at Yonge St.), Toronto ON, Canada]
# 59c54d4f2d2fd97564d4cfc8     [40 Hayden Street, Toronto ON M4Y 1V8, Canada]
# 527428a5498e8e23580dbe15  [687 Yonge St (at Charles St), Toronto ON M6H ...
# 4c531b60a724e21e029e3af4  [459 Church St (Alexander St), Toronto ON M4Y ...
# 4af0b965f964a52094de21e3  [640 Church St. (at Hayden St.), Toronto ON M4...
#
#                                                          venue.canonicalUrl  \
# venue.id
# 50e88fc6e4b007fcbb57aae8  https://foursquare.com/v/izumi/50e88fc6e4b007f...
# 4ccc5aebee23a14370591ea8  https://foursquare.com/v/lac-vien-vietnamese-r...
# 4afca145f964a5208e2422e3  https://foursquare.com/v/tokyo-sushi/4afca145f...
# 4ba6b463f964a520416a39e3  https://foursquare.com/v/sushi-garden/4ba6b463...
# 4ad4c061f964a520abf720e3  https://foursquare.com/v/tokyo-grill/4ad4c061f...
# ...                                                                     ...
# 4ae787b9f964a52020ac21e3  https://foursquare.com/v/tokyo-kitchen/4ae787b...
# 59c54d4f2d2fd97564d4cfc8  https://foursquare.com/v/onnki-donburi/59c54d4...
# 527428a5498e8e23580dbe15  https://foursquare.com/v/miss-korea/527428a549...
# 4c531b60a724e21e029e3af4  https://foursquare.com/v/kokoni-izakaya/4c531b...
# 4af0b965f964a52094de21e3  https://foursquare.com/v/asahi-sushi/4af0b965f...
#
#                           ... venue.parent.location.labeledLatLngs  \
# venue.id                  ...
# 50e88fc6e4b007fcbb57aae8  ...                                  NaN
# 4ccc5aebee23a14370591ea8  ...                                  NaN
# 4afca145f964a5208e2422e3  ...                                  NaN
# 4ba6b463f964a520416a39e3  ...                                  NaN
# 4ad4c061f964a520abf720e3  ...                                  NaN
# ...                       ...                                  ...
# 4ae787b9f964a52020ac21e3  ...                                  NaN
# 59c54d4f2d2fd97564d4cfc8  ...                                  NaN
# 527428a5498e8e23580dbe15  ...                                  NaN
# 4c531b60a724e21e029e3af4  ...                                  NaN
# 4af0b965f964a52094de21e3  ...                                  NaN
#
#                           venue.parent.location.postalCode  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                               NaN
# 4ccc5aebee23a14370591ea8                               NaN
# 4afca145f964a5208e2422e3                               NaN
# 4ba6b463f964a520416a39e3                               NaN
# 4ad4c061f964a520abf720e3                               NaN
# ...                                                    ...
# 4ae787b9f964a52020ac21e3                               NaN
# 59c54d4f2d2fd97564d4cfc8                               NaN
# 527428a5498e8e23580dbe15                               NaN
# 4c531b60a724e21e029e3af4                               NaN
# 4af0b965f964a52094de21e3                               NaN
#
#                           venue.parent.location.cc  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                       NaN
# 4ccc5aebee23a14370591ea8                       NaN
# 4afca145f964a5208e2422e3                       NaN
# 4ba6b463f964a520416a39e3                       NaN
# 4ad4c061f964a520abf720e3                       NaN
# ...                                            ...
# 4ae787b9f964a52020ac21e3                       NaN
# 59c54d4f2d2fd97564d4cfc8                       NaN
# 527428a5498e8e23580dbe15                       NaN
# 4c531b60a724e21e029e3af4                       NaN
# 4af0b965f964a52094de21e3                       NaN
#
#                           venue.parent.location.city  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                         NaN
# 4ccc5aebee23a14370591ea8                         NaN
# 4afca145f964a5208e2422e3                         NaN
# 4ba6b463f964a520416a39e3                         NaN
# 4ad4c061f964a520abf720e3                         NaN
# ...                                              ...
# 4ae787b9f964a52020ac21e3                         NaN
# 59c54d4f2d2fd97564d4cfc8                         NaN
# 527428a5498e8e23580dbe15                         NaN
# 4c531b60a724e21e029e3af4                         NaN
# 4af0b965f964a52094de21e3                         NaN
#
#                          venue.parent.location.state  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                         NaN
# 4ccc5aebee23a14370591ea8                         NaN
# 4afca145f964a5208e2422e3                         NaN
# 4ba6b463f964a520416a39e3                         NaN
# 4ad4c061f964a520abf720e3                         NaN
# ...                                              ...
# 4ae787b9f964a52020ac21e3                         NaN
# 59c54d4f2d2fd97564d4cfc8                         NaN
# 527428a5498e8e23580dbe15                         NaN
# 4c531b60a724e21e029e3af4                         NaN
# 4af0b965f964a52094de21e3                         NaN
#
#                          venue.parent.location.country  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                           NaN
# 4ccc5aebee23a14370591ea8                           NaN
# 4afca145f964a5208e2422e3                           NaN
# 4ba6b463f964a520416a39e3                           NaN
# 4ad4c061f964a520abf720e3                           NaN
# ...                                                ...
# 4ae787b9f964a52020ac21e3                           NaN
# 59c54d4f2d2fd97564d4cfc8                           NaN
# 527428a5498e8e23580dbe15                           NaN
# 4c531b60a724e21e029e3af4                           NaN
# 4af0b965f964a52094de21e3                           NaN
#
#                           venue.parent.location.formattedAddress  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                                     NaN
# 4ccc5aebee23a14370591ea8                                     NaN
# 4afca145f964a5208e2422e3                                     NaN
# 4ba6b463f964a520416a39e3                                     NaN
# 4ad4c061f964a520abf720e3                                     NaN
# ...                                                          ...
# 4ae787b9f964a52020ac21e3                                     NaN
# 59c54d4f2d2fd97564d4cfc8                                     NaN
# 527428a5498e8e23580dbe15                                     NaN
# 4c531b60a724e21e029e3af4                                     NaN
# 4af0b965f964a52094de21e3                                     NaN
#
#                          venue.parent.categories venue.hierarchy  \
# venue.id
# 50e88fc6e4b007fcbb57aae8                     NaN             NaN
# 4ccc5aebee23a14370591ea8                     NaN             NaN
# 4afca145f964a5208e2422e3                     NaN             NaN
# 4ba6b463f964a520416a39e3                     NaN             NaN
# 4ad4c061f964a520abf720e3                     NaN             NaN
# ...                                          ...             ...
# 4ae787b9f964a52020ac21e3                     NaN             NaN
# 59c54d4f2d2fd97564d4cfc8                     NaN             NaN
# 527428a5498e8e23580dbe15                     NaN             NaN
# 4c531b60a724e21e029e3af4                     NaN             NaN
# 4af0b965f964a52094de21e3                     NaN             NaN
#
#                           venue.parent.location.neighborhood
# venue.id
# 50e88fc6e4b007fcbb57aae8                                 NaN
# 4ccc5aebee23a14370591ea8                                 NaN
# 4afca145f964a5208e2422e3                                 NaN
# 4ba6b463f964a520416a39e3                                 NaN
# 4ad4c061f964a520abf720e3                                 NaN
# ...                                                      ...
# 4ae787b9f964a52020ac21e3                                 NaN
# 59c54d4f2d2fd97564d4cfc8                                 NaN
# 527428a5498e8e23580dbe15                                 NaN
# 4c531b60a724e21e029e3af4                                 NaN
# 4af0b965f964a52094de21e3                                 NaN
#
# [119 rows x 142 columns]

# %%
#
# Join key data fields to the restaurants data frame and identify the dupes
#
key_venue_cols = [
    'venue.location.address',
    'venue.location.postalCode',
    'venue.stats.tipCount',
    'venue.price.tier',
    'venue.rating',
    'venue.likes.count'
]
asian_restaurants = asian_restaurants.join(asian_venue_data_df[key_venue_cols], on='Venue ID')

# Cleanup
asian_restaurants.rename(columns={
    'venue.location.address': 'Venue Address',
    'venue.location.postalCode': 'Venue Postal Code',
    'venue.stats.tipCount': 'Venue Tip Count',
    'venue.price.tier': 'Venue Price Tier',
    'venue.rating': 'Venue Rating',
    'venue.likes.count': 'Venue Likes'
}, inplace=True)
asian_restaurants['Venue Price Tier'] = asian_restaurants['Venue Price Tier'].astype(pd.Int64Dtype())
asian_restaurants
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0            M5A              43.654260              -79.360636
# 1            M6A              43.718518              -79.464763
# 2            M7A              43.662301              -79.389494
# 3            M7A              43.662301              -79.389494
# 4            M7A              43.662301              -79.389494
# ..           ...                    ...                     ...
# 140          M4Y              43.665860              -79.383160
# 141          M4Y              43.665860              -79.383160
# 142          M4Y              43.665860              -79.383160
# 143          M4Y              43.665860              -79.383160
# 144          M4Y              43.665860              -79.383160
#
#                               Venue                  Venue ID  Venue Latitude  \
# 0                             Izumi  50e88fc6e4b007fcbb57aae8       43.649970
# 1    Lac Vien Vietnamese Restaurant  4ccc5aebee23a14370591ea8       43.721259
# 2                       Tokyo Sushi  4afca145f964a5208e2422e3       43.665885
# 3                      Sushi Garden  4ba6b463f964a520416a39e3       43.664858
# 4                       Tokyo Grill  4ad4c061f964a520abf720e3       43.665085
# ..                              ...                       ...             ...
# 140                   Tokyo Kitchen  4ae787b9f964a52020ac21e3       43.668783
# 141                   Onnki Donburi  59c54d4f2d2fd97564d4cfc8       43.669757
# 142                      Miss Korea  527428a5498e8e23580dbe15       43.668950
# 143                  Kokoni Izakaya  4c531b60a724e21e029e3af4       43.664181
# 144                     Asahi Sushi  4af0b965f964a52094de21e3       43.669874
#
#      Venue Longitude         Venue Category       Venue Address  \
# 0         -79.360153       Asian Restaurant                 NaN
# 1         -79.468472  Vietnamese Restaurant  141 Cartwright Ave
# 2         -79.386977       Sushi Restaurant   33 St. Joseph St.
# 3         -79.384941       Sushi Restaurant    3 Wellesley St W
# 4         -79.384707    Japanese Restaurant        582 Yonge St
# ..               ...                    ...                 ...
# 140       -79.385153    Japanese Restaurant         Charles St.
# 141       -79.384574    Japanese Restaurant    40 Hayden Street
# 142       -79.386165      Korean Restaurant        687 Yonge St
# 143       -79.380258    Japanese Restaurant       459 Church St
# 144       -79.382943       Sushi Restaurant      640 Church St.
#
#     Venue Postal Code  Venue Tip Count  Venue Price Tier  Venue Rating  \
# 0                 NaN                4                 2           7.4
# 1                 NaN               12                 2           7.6
# 2             M4Y 1J8               24                 2           8.1
# 3                 NaN                9                 2           7.7
# 4             M4Y 1Z3               29                 1           7.7
# ..                ...              ...               ...           ...
# 140               NaN               21                 2           7.4
# 141           M4Y 1V8                3                 2           7.7
# 142           M6H 2C9               17                 2           7.5
# 143           M4Y 2C5                9                 2           6.6
# 144           M4W 3T5               30                 2           6.3
#
#      Venue Likes
# 0             18
# 1             29
# 2             32
# 3              9
# 4             35
# ..           ...
# 140           20
# 141           13
# 142           32
# 143            1
# 144           22
#
# [145 rows x 14 columns]

# %% [markdown]
# #### The Problem of Duplicates
# Initially I was surprised to find only 119 venues for 145 venues in the original dataframe. This means the dataframe above has duplicates. However, on further inspection, it seems reasonable since we didn't explore by _FSA_ rather by _distance from the FSA centroids_. This means a restaurant could (and actually did) show up under multiple FSAs. This begged the question: _To which FSA should each venue be assigned?_ I went with the officially assigned FSA for simplicity. Nominatum was very handy for filling in the blanks in the Foursquare data by leveraging the `Venue Address` to do geocode lookups. As a last resort, I did a reverse lookup on the `Venue Latitude` and `Venue Longitude` to find the postal code. (Unfortunately the exact addresses didn't seem to match the venues so I ignored them.)

# %%
# 
# Create masks to filter the dataframe
#

postalcode_mask = pd.notna(asian_restaurants['Venue Postal Code'])
postcode_match_mask = (asian_restaurants['Venue Postal Code'].str.extract('^(\w{3})', expand=False) == asian_restaurants['Neighborhood'])
address_mask = pd.notna(asian_restaurants['Venue Address'])

# Venues with mismatched postal codes
pd.set_option('max_rows', 200)
asian_restaurants[['Venue','Neighborhood','Venue Postal Code', 'Venue Address']].loc[~postcode_match_mask]
# Out:
#                                   Venue Neighborhood Venue Postal Code  \
# 0                                 Izumi          M5A               NaN
# 1        Lac Vien Vietnamese Restaurant          M6A               NaN
# 2                           Tokyo Sushi          M7A           M4Y 1J8
# 3                          Sushi Garden          M7A               NaN
# 4                           Tokyo Grill          M7A           M4Y 1Z3
# 10               GB Hand-Pulled Noodles          M5B           M5G 1C9
# 12                                 KAKA          M5B           M5G 1Z4
# 14              Miyako Sushi Restaurant          M6B               NaN
# 15                  Li Cheng Restaurant          M6B               NaN
# 16                         Asian Legend          M3C               NaN
# 18                          Pho 88 發發餐廳          M3C               NaN
# 19                          Bento Sushi          M3C               NaN
# 21                            Sukhothai          M5C           M5E 1C9
# 22                           Sweet Lulu          M5C               NaN
# 24                         Chotto Matte          M5E           M5J 2S4
# 25                   Korean Grill House          M1G               NaN
# 29                         Thai Express          M5G           M5S 1B2
# 30                                 Omai          M5G           M5T 1L1
# 31                            Mo'Ramyun          M5G           M5T 1L1
# 36                             JaBistro          M5H           M5V 1W4
# 38             Fune Japanese Restaurant          M5H               NaN
# 39                    Queen Mother Cafe          M5H           M5V 1Z2
# 42     Ruby Thai (First Canadian Place)          M5H               NaN
# 45                           Manchu Wok          M2J               NaN
# 48                       Phở Liên Hương          M3J               NaN
# 51      Gonoe Sushi Japanese Restaurant          M5J               NaN
# 55                               Bazara          M6J               NaN
# 56                              Hanmoto          M6J           M5C 1X6
# 57                       Pho Tien Thanh          M6J               NaN
# 59                           Kaga Sushi          M2K               NaN
# 60             Ki Modern Japanese + Bar          M5K           M5J 2T3
# 61                         Chotto Matte          M5K           M5J 2S4
# 62                   Bosk at Shangri-La          M5K           M5H 0A3
# 63                        Ninki Izakaya          M5K               NaN
# 64                           Sweet Lulu          M5K               NaN
# 65                                Tachi          M5K           M5H 2G4
# 66                     Szechuan Express          M5K               NaN
# 67                              Sushi-Q          M5K           M5H 1T1
# 68                              O Sushi          M4L               NaN
# 69             Ki Modern Japanese + Bar          M5L           M5J 2T3
# 70                         Chotto Matte          M5L           M5J 2S4
# 71                            Sukhothai          M5L           M5E 1C9
# 72                           Sweet Lulu          M5L               NaN
# 73     Ruby Thai (First Canadian Place)          M5L               NaN
# 74                                 NAMI          M5L           M5C 1K6
# 76                        Sakura Garden          M5M               NaN
# 79                     Wako Sushi + Bar          M2N               NaN
# 83            Pho 88 Vietnamese Cuisine          M2N               NaN
# 87      Nikko Sushi Japenese Restaurant          M5P           M5N 1A2
# 89                                 Silk          M6P               NaN
# 92                            C'est Bon          M4R           M4N 2H8
# 93                          Sakae Sushi          M4S               NaN
# 94                     Thai Spicy House          M4S               NaN
# 95                       Hokkaido Sushi          M4S           M4P 3C2
# 99                            Asa Sushi          M6S               NaN
# 100                          Yumi Sushi          M6S               NaN
# 101  The Royal Chinese Restaurant 避風塘小炒          M1T               NaN
# 110                         Daeco Sushi          M4V               NaN
# 113                           Sukhothai          M5W           M5E 1C9
# 114            Ki Modern Japanese + Bar          M5W           M5J 2T3
# 115                        Chotto Matte          M5W           M5J 2S4
# 116                                NAMI          M5W           M5C 1K6
# 118                    Kanpai Snack Bar          M4X               NaN
# 119                 Thai Room - Carlton          M4X           M5A 2L2
# 120                       China Gourmet          M4X           M5A 2L2
# 121            Ki Modern Japanese + Bar          M5X           M5J 2T3
# 122                  Bosk at Shangri-La          M5X           M5H 0A3
# 123                               Tachi          M5X           M5H 2G4
# 124                       Ninki Izakaya          M5X               NaN
# 125                          Sweet Lulu          M5X               NaN
# 126            Fune Japanese Restaurant          M5X               NaN
# 127                        Chotto Matte          M5X           M5J 2S4
# 128                         Noodle King          M5X           M5H 3M9
# 129                         Thai Island          M5X           M5H 3T9
# 130                            JaBistro          M5X           M5V 1W4
# 131    Ruby Thai (First Canadian Place)          M5X               NaN
# 135                        Sushi Garden          M4Y               NaN
# 137                          Kawa Sushi          M4Y               NaN
# 140                       Tokyo Kitchen          M4Y               NaN
# 142                          Miss Korea          M4Y           M6H 2C9
# 144                         Asahi Sushi          M4Y           M4W 3T5
#
#                 Venue Address
# 0                         NaN
# 1          141 Cartwright Ave
# 2           33 St. Joseph St.
# 3            3 Wellesley St W
# 4                582 Yonge St
# 10           66 Edward Street
# 12             655 Bay Street
# 14             572 Marlee Ave
# 15          529 Marlee Avenue
# 16                        NaN
# 18         900 Don Mills Road
# 19                        NaN
# 21       52 Wellington St. E.
# 22                 350 Bay St
# 24                 161 Bay St
# 25           369 Yonge Street
# 29            76 Grenville St
# 30               3 Baldwin St
# 31              1 Baldwin St.
# 36          222 Richmond St W
# 38             100 Simcoe St.
# 39            208 Queen St. W
# 42                        NaN
# 45              Fairview Mall
# 48        1300 Finch Ave West
# 51          262 Queens Quay W
# 55              188 Ossington
# 56           2 Lakeview Drive
# 57          57 Ossington Ave.
# 59            652 Finch Ave E
# 60                 181 Bay St
# 61                 161 Bay St
# 62        188 University Ave.
# 63   133 Richmond Street West
# 64                 350 Bay St
# 65          111 Richmond St W
# 66                200 Bay St.
# 67                    199 Bay
# 68                  6 Coxwell
# 69                 181 Bay St
# 70                 161 Bay St
# 71       52 Wellington St. E.
# 72                 350 Bay St
# 73                        NaN
# 74    55 Adelaide Street East
# 76           1921 Avenue road
# 79          5213 Yonge Street
# 83              5197 Yonge St
# 87        376 Eglinton Ave. W
# 89    2907 dundas street west
# 92              2685 Yonge St
# 93        643a Mt Pleasant Rd
# 94    517 Mount Pleasant Road
# 95        245 Eglinton Ave. E
# 99                18 Jane St.
# 100    2384 Bloor Street West
# 101       3587 Sheppard Ave E
# 110         40 St. Clair West
# 113      52 Wellington St. E.
# 114                181 Bay St
# 115                161 Bay St
# 116   55 Adelaide Street East
# 118            252 Carlton St
# 119            243 Carlton St
# 120            235 Carlton St
# 121                181 Bay St
# 122       188 University Ave.
# 123         111 Richmond St W
# 124  133 Richmond Street West
# 125                350 Bay St
# 126            100 Simcoe St.
# 127                161 Bay St
# 128          123 Queen St. W.
# 129            130 King St. W
# 130         222 Richmond St W
# 131                       NaN
# 135          3 Wellesley St W
# 137            451 Church St.
# 140               Charles St.
# 142              687 Yonge St
# 144            640 Church St.

# %% [markdown]
# As we can see there are a lot of mismatches in the data. The FSAs that we initially set as `Neighborhood` don't match the offical FSA in `Postal Code`. The good news is that most of them were pretty close so that bodes well for me to start adjusting the `Neighborhood` column to reflect the "true" FSA. The first thing to do is adjust the known FSAs.

# %%
# Adjust Neighborhood to known FSA
mask = postalcode_mask & ~postcode_match_mask
asian_restaurants.loc[ mask, 'Neighborhood'] = asian_restaurants.loc[mask, 'Venue Postal Code'].str.extract('^(\w{3})', expand=False)

# Reset masks
postalcode_mask = pd.notna(asian_restaurants['Venue Postal Code'])
postcode_match_mask = (asian_restaurants['Venue Postal Code'].str.extract('^(\w{3})', expand=False) == asian_restaurants['Neighborhood'])
address_mask = pd.notna(asian_restaurants['Venue Address'])

# Check results
asian_restaurants[['Venue','Neighborhood','Venue Postal Code', 'Venue Address']].loc[~postcode_match_mask]
# Out:
#                                   Venue Neighborhood Venue Postal Code  \
# 0                                 Izumi          M5A               NaN
# 1        Lac Vien Vietnamese Restaurant          M6A               NaN
# 3                          Sushi Garden          M7A               NaN
# 14              Miyako Sushi Restaurant          M6B               NaN
# 15                  Li Cheng Restaurant          M6B               NaN
# 16                         Asian Legend          M3C               NaN
# 18                          Pho 88 發發餐廳          M3C               NaN
# 19                          Bento Sushi          M3C               NaN
# 22                           Sweet Lulu          M5C               NaN
# 25                   Korean Grill House          M1G               NaN
# 38             Fune Japanese Restaurant          M5H               NaN
# 42     Ruby Thai (First Canadian Place)          M5H               NaN
# 45                           Manchu Wok          M2J               NaN
# 48                       Phở Liên Hương          M3J               NaN
# 51      Gonoe Sushi Japanese Restaurant          M5J               NaN
# 55                               Bazara          M6J               NaN
# 57                       Pho Tien Thanh          M6J               NaN
# 59                           Kaga Sushi          M2K               NaN
# 63                        Ninki Izakaya          M5K               NaN
# 64                           Sweet Lulu          M5K               NaN
# 66                     Szechuan Express          M5K               NaN
# 68                              O Sushi          M4L               NaN
# 72                           Sweet Lulu          M5L               NaN
# 73     Ruby Thai (First Canadian Place)          M5L               NaN
# 76                        Sakura Garden          M5M               NaN
# 79                     Wako Sushi + Bar          M2N               NaN
# 83            Pho 88 Vietnamese Cuisine          M2N               NaN
# 89                                 Silk          M6P               NaN
# 93                          Sakae Sushi          M4S               NaN
# 94                     Thai Spicy House          M4S               NaN
# 99                            Asa Sushi          M6S               NaN
# 100                          Yumi Sushi          M6S               NaN
# 101  The Royal Chinese Restaurant 避風塘小炒          M1T               NaN
# 110                         Daeco Sushi          M4V               NaN
# 118                    Kanpai Snack Bar          M4X               NaN
# 124                       Ninki Izakaya          M5X               NaN
# 125                          Sweet Lulu          M5X               NaN
# 126            Fune Japanese Restaurant          M5X               NaN
# 131    Ruby Thai (First Canadian Place)          M5X               NaN
# 135                        Sushi Garden          M4Y               NaN
# 137                          Kawa Sushi          M4Y               NaN
# 140                       Tokyo Kitchen          M4Y               NaN
#
#                 Venue Address
# 0                         NaN
# 1          141 Cartwright Ave
# 3            3 Wellesley St W
# 14             572 Marlee Ave
# 15          529 Marlee Avenue
# 16                        NaN
# 18         900 Don Mills Road
# 19                        NaN
# 22                 350 Bay St
# 25           369 Yonge Street
# 38             100 Simcoe St.
# 42                        NaN
# 45              Fairview Mall
# 48        1300 Finch Ave West
# 51          262 Queens Quay W
# 55              188 Ossington
# 57          57 Ossington Ave.
# 59            652 Finch Ave E
# 63   133 Richmond Street West
# 64                 350 Bay St
# 66                200 Bay St.
# 68                  6 Coxwell
# 72                 350 Bay St
# 73                        NaN
# 76           1921 Avenue road
# 79          5213 Yonge Street
# 83              5197 Yonge St
# 89    2907 dundas street west
# 93        643a Mt Pleasant Rd
# 94    517 Mount Pleasant Road
# 99                18 Jane St.
# 100    2384 Bloor Street West
# 101       3587 Sheppard Ave E
# 110         40 St. Clair West
# 118            252 Carlton St
# 124  133 Richmond Street West
# 125                350 Bay St
# 126            100 Simcoe St.
# 131                       NaN
# 135          3 Wellesley St W
# 137            451 Church St.
# 140               Charles St.

# %% [markdown]
# Now we have venues with no postal code but we _do_ have an address. Time to engage Nominatum to see if the geocoder can get us the postal code.

# %%
# Use the Nominatum geocoder to get the postal code data
geolocator = Nominatim(user_agent="robs_ba_explorer")
mask = ~postalcode_mask & ~postcode_match_mask & address_mask
postal_codes = pd.Series(dtype='object')
for address in asian_restaurants.loc[ mask, 'Venue Address']:
    location = geolocator.geocode(address + ", Toronto, ON")
    postal_codes[address] = location.address
postal_codes = postal_codes.str.extract("Ontario, (\w{3}(?:\s{1}\w{3})?).*$")   
postal_codes
# Out:
#                                 0
# 141 Cartwright Ave        M6A 2X3
# 3 Wellesley St W          M4Y 1E7
# 572 Marlee Ave            M6B 2A2
# 529 Marlee Avenue         M6B 2A2
# 900 Don Mills Road        M3C 2H2
# 350 Bay St                    M5H
# 369 Yonge Street          M5B 1R8
# 100 Simcoe St.                M5H
# Fairview Mall             M2J 5A7
# 1300 Finch Ave West       M3J 3K2
# 262 Queens Quay W         M5J 1B5
# 188 Ossington             M6G 1M4
# 57 Ossington Ave.         M6J 2Y9
# 652 Finch Ave E           M2K 1G3
# 133 Richmond Street West      M5H
# 200 Bay St.               M5J 2S1
# 6 Coxwell                 M4C 3J6
# 1921 Avenue road          M5M 3Z6
# 5213 Yonge Street         M2N 5P8
# 5197 Yonge St             M2N 5P7
# 2907 dundas street west       M6P
# 643a Mt Pleasant Rd       M4S 2N3
# 517 Mount Pleasant Road   M4S 2M2
# 18 Jane St.                   M6S
# 2384 Bloor Street West        M6S
# 3587 Sheppard Ave E       M1T 3K7
# 40 St. Clair West         M6C 1A1
# 252 Carlton St            M5A 2L3
# 451 Church St.            M4Y 2C5
# Charles St.               M4Y 1Z8

# %%
# Loop through and set the Postal Code 
for index in asian_restaurants.loc[mask].index:
    asian_restaurants.loc[index, 'Venue Postal Code'] = postal_codes.loc[asian_restaurants.loc[index, 'Venue Address'], 0]

# Reset masks
postalcode_mask = pd.notna(asian_restaurants['Venue Postal Code'])
postcode_match_mask = (asian_restaurants['Venue Postal Code'].str.extract('^(\w{3})', expand=False) == asian_restaurants['Neighborhood'])
address_mask = pd.notna(asian_restaurants['Venue Address'])
mask = ~postcode_match_mask & address_mask

# Check results
asian_restaurants[['Venue','Neighborhood','Venue Postal Code', 'Venue Address']].loc[mask]
# Out:
#                         Venue Neighborhood Venue Postal Code  \
# 3                Sushi Garden          M7A           M4Y 1E7
# 22                 Sweet Lulu          M5C               M5H
# 25         Korean Grill House          M1G           M5B 1R8
# 55                     Bazara          M6J           M6G 1M4
# 63              Ninki Izakaya          M5K               M5H
# 64                 Sweet Lulu          M5K               M5H
# 66           Szechuan Express          M5K           M5J 2S1
# 68                    O Sushi          M4L           M4C 3J6
# 72                 Sweet Lulu          M5L               M5H
# 110               Daeco Sushi          M4V           M6C 1A1
# 118          Kanpai Snack Bar          M4X           M5A 2L3
# 124             Ninki Izakaya          M5X               M5H
# 125                Sweet Lulu          M5X               M5H
# 126  Fune Japanese Restaurant          M5X               M5H
#
#                 Venue Address
# 3            3 Wellesley St W
# 22                 350 Bay St
# 25           369 Yonge Street
# 55              188 Ossington
# 63   133 Richmond Street West
# 64                 350 Bay St
# 66                200 Bay St.
# 68                  6 Coxwell
# 72                 350 Bay St
# 110         40 St. Clair West
# 118            252 Carlton St
# 124  133 Richmond Street West
# 125                350 Bay St
# 126            100 Simcoe St.

# %%
# Update the Neighborhood to match the FSA in the Postal Code
asian_restaurants.loc[ mask, 'Neighborhood'] = asian_restaurants.loc[mask, 'Venue Postal Code'].str.extract('^(\w{3})', expand=False)
asian_restaurants[['Venue','Neighborhood','Venue Postal Code', 'Venue Address']].loc[mask]
# Out:
#                         Venue Neighborhood Venue Postal Code  \
# 3                Sushi Garden          M4Y           M4Y 1E7
# 22                 Sweet Lulu          M5H               M5H
# 25         Korean Grill House          M5B           M5B 1R8
# 55                     Bazara          M6G           M6G 1M4
# 63              Ninki Izakaya          M5H               M5H
# 64                 Sweet Lulu          M5H               M5H
# 66           Szechuan Express          M5J           M5J 2S1
# 68                    O Sushi          M4C           M4C 3J6
# 72                 Sweet Lulu          M5H               M5H
# 110               Daeco Sushi          M6C           M6C 1A1
# 118          Kanpai Snack Bar          M5A           M5A 2L3
# 124             Ninki Izakaya          M5H               M5H
# 125                Sweet Lulu          M5H               M5H
# 126  Fune Japanese Restaurant          M5H               M5H
#
#                 Venue Address
# 3            3 Wellesley St W
# 22                 350 Bay St
# 25           369 Yonge Street
# 55              188 Ossington
# 63   133 Richmond Street West
# 64                 350 Bay St
# 66                200 Bay St.
# 68                  6 Coxwell
# 72                 350 Bay St
# 110         40 St. Clair West
# 118            252 Carlton St
# 124  133 Richmond Street West
# 125                350 Bay St
# 126            100 Simcoe St.

# %%
# Find remaining venues that need to be adjusted
mask = ~postcode_match_mask & ~postalcode_mask
asian_restaurants.loc[~postcode_match_mask & ~postalcode_mask]
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0            M5A              43.654260              -79.360636
# 16           M3C              43.725900              -79.340923
# 19           M3C              43.725900              -79.340923
# 42           M5H              43.650571              -79.384568
# 73           M5L              43.648198              -79.379817
# 131          M5X              43.648429              -79.382280
#
#                                 Venue                  Venue ID  \
# 0                               Izumi  50e88fc6e4b007fcbb57aae8
# 16                       Asian Legend  5686b77338faf7478eb6c6aa
# 19                        Bento Sushi  4d6be9dd1013236abc9cb5f9
# 42   Ruby Thai (First Canadian Place)  5632426a498e0433cad5aa04
# 73   Ruby Thai (First Canadian Place)  5632426a498e0433cad5aa04
# 131  Ruby Thai (First Canadian Place)  5632426a498e0433cad5aa04
#
#      Venue Latitude  Venue Longitude      Venue Category Venue Address  \
# 0         43.649970       -79.360153    Asian Restaurant           NaN
# 16        43.726591       -79.342188  Dim Sum Restaurant           NaN
# 19        43.722265       -79.337631    Sushi Restaurant           NaN
# 42        43.649091       -79.381600     Thai Restaurant           NaN
# 73        43.649091       -79.381600     Thai Restaurant           NaN
# 131       43.649091       -79.381600     Thai Restaurant           NaN
#
#     Venue Postal Code  Venue Tip Count  Venue Price Tier  Venue Rating  \
# 0                 NaN                4                 2           7.4
# 16                NaN                4                 2           6.5
# 19                NaN                1                 2           NaN
# 42                NaN                2                 2           7.1
# 73                NaN                2                 2           7.1
# 131               NaN                2                 2           7.1
#
#      Venue Likes
# 0             18
# 16            13
# 19             0
# 42             7
# 73             7
# 131            7

# %%
# Do a reverse geocode lookup and extract postal code from address found
p = re.compile(r"Ontario, (\w{3}(?:\s{1}\w{3})?).*$")
for index in asian_restaurants[mask].index:
    location = geolocator.reverse("{}, {}".format(asian_restaurants.loc[index, 'Venue Latitude'], asian_restaurants.loc[index, 'Venue Longitude']))
    m = p.search(location.address)
    asian_restaurants.loc[index, 'Venue Postal Code'] = m.group(1)
    asian_restaurants.loc[index, 'Neighborhood'] = m.group(1)[0:3]
asian_restaurants
# Out:
# tnamese Restaurant
# 106       43.652722       -79.398498    Dumpling Restaurant
# 107       43.652167       -79.404843    Filipino Restaurant
# 108       43.652258       -79.404884    Japanese Restaurant
# 109       43.652832       -79.406242  Vietnamese Restaurant
# 110       43.687838       -79.395652       Sushi Restaurant
# 111       43.687996       -79.394651  Vietnamese Restaurant
# 112       43.798879       -79.318335     Chinese Restaurant
# 113       43.648487       -79.374547        Thai Restaurant
# 114       43.647223       -79.379374    Japanese Restaurant
# 115       43.646473       -79.378782    Japanese Restaurant
# 116       43.650853       -79.375887    Japanese Restaurant
# 117       43.665895       -79.368415    Japanese Restaurant
# 118       43.664331       -79.368065   Taiwanese Restaurant
# 119       43.664159       -79.368189        Thai Restaurant
# 120       43.664180       -79.368359     Chinese Restaurant
# 121       43.647223       -79.379374    Japanese Restaurant
# 122       43.649023       -79.385826       Asian Restaurant
# 123       43.650596       -79.383396       Sushi Restaurant
# 124       43.650228       -79.384863    Japanese Restaurant
# 125       43.650557       -79.381175       Asian Restaurant
# 126       43.648514       -79.386457    Japanese Restaurant
# 127       43.646473       -79.378782    Japanese Restaurant
# 128       43.651706       -79.383046       Asian Restaurant
# 129       43.649146       -79.383798        Thai Restaurant
# 130       43.649687       -79.388090       Sushi Restaurant
# 131       43.649091       -79.381600        Thai Restaurant
# 132       43.666735       -79.385353       Ramen Restaurant
# 133       43.665010       -79.380683        Thai Restaurant
# 134       43.665085       -79.384707    Japanese Restaurant
# 135       43.664858       -79.384941       Sushi Restaurant
# 136       43.665885       -79.386977       Sushi Restaurant
# 137       43.663894       -79.380210    Japanese Restaurant
# 138       43.668514       -79.386686       Sushi Restaurant
# 139       43.669388       -79.386566       Sushi Restaurant
# 140       43.668783       -79.385153    Japanese Restaurant
# 141       43.669757       -79.384574    Japanese Restaurant
# 142       43.668950       -79.386165      Korean Restaurant
# 143       43.664181       -79.380258    Japanese Restaurant
# 144       43.669874       -79.382943       Sushi Restaurant
#
#                  Venue Address Venue Postal Code  Venue Tip Count  \
# 0                          NaN           M5A 3C4                4
# 1           141 Cartwright Ave           M6A 2X3               12
# 2            33 St. Joseph St.           M4Y 1J8               24
# 3             3 Wellesley St W           M4Y 1E7                9
# 4                 582 Yonge St           M4Y 1Z3               29
# 5    1310 Don Mills Rd, Unit 1           M3B 2W6               14
# 6               91 Dundas St E           M5B 1E1              121
# 7                 340 Yonge St           M5B 1R7              214
# 8                398 Church St           M5B 2A2              219
# 9                396 Church St           M5B 2A2               17
# 10            66 Edward Street           M5G 1C9                9
# 11             66 Gerrard St E           M5B 1G3                3
# 12              655 Bay Street           M5G 1Z4                2
# 13               271 Yonge St.           M5B 1N8               20
# 14              572 Marlee Ave           M6B 2A2                3
# 15           529 Marlee Avenue           M6B 2A2                3
# 16                         NaN           M3C 2H2                4
# 17           900 Don Mills Rd.           M3C 1V6               13
# 18          900 Don Mills Road           M3C 2H2               10
# 19                         NaN           M3C 1V4                1
# 20                81 Church St           M5C 2G2               11
# 21        52 Wellington St. E.           M5E 1C9               86
# 22                  350 Bay St               M5H               11
# 23        52 Wellington St. E.           M5E 1C9               86
# 24                  161 Bay St           M5J 2S4                2
# 25            369 Yonge Street           M5B 1R8                0
# 26             214 Laird drive           M4G 3W4               10
# 27             207 Dundas St W           M5G 1C8                4
# 28           122 Elizabeth St.           M5G 1P5               90
# 29             76 Grenville St           M5S 1B2                0
# 30                3 Baldwin St           M5T 1L1                4
# 31               1 Baldwin St.           M5T 1L1                8
# 32         1911 Ellesmere Road           M1H 2W5                8
# 33          638 Sheppard Ave W           M3H 2S1               24
# 34    554 Sheppard Avenue West           M3H 2R9                2
# 35         188 University Ave.           M5H 0A3               32
# 36           222 Richmond St W           M5V 1W4               72
# 37                18 Duncan St           M5H 3G6              207
# 38              100 Simcoe St.               M5H               27
# 39             208 Queen St. W           M5V 1Z2               85
# 40          236 Adelaide St. W           M5H 1W7               53
# 41              130 King St. W           M5H 3T9                7
# 42                         NaN               M5H                2
# 43      1800 Sheppard Avenue E               M2J                3
# 44        1800 Sheppard Ave. E           M2J 5A7               28
# 45               Fairview Mall           M2J 5A7                0
# 46        1800 Sheppard Ave. E           M2J 5A7                1
# 47      1800 Sheppard Ave West           M2J 5A7                0
# 48         1300 Finch Ave West           M3J 3K2                0
# 49                   10 Bay St           M5J 2R8               47
# 50      200-207 Queens Quay W.           M5J 1A7               34
# 51           262 Queens Quay W           M5J 1B5               12
# 52           207 Ossington Ave           M6J 2Z8               53
# 53           90 Ossington Ave.           M6J 2Z4               72
# 54          125 Ossington Ave.           M6J 2Z2               80
# 55               188 Ossington           M6G 1M4               15
# 56            2 Lakeview Drive           M5C 1X6               22
# 57           57 Ossington Ave.           M6J 2Y9               75
# 58       636 Finch Avenue East           M2K 2E6                0
# 59             652 Finch Ave E           M2K 1G3                4
# 60                  181 Bay St           M5J 2T3               61
# 61                  161 Bay St           M5J 2S4                2
# 62         188 University Ave.           M5H 0A3               32
# 63    133 Richmond Street West               M5H                5
# 64                  350 Bay St               M5H               11
# 65           111 Richmond St W           M5H 2G4                1
# 66                 200 Bay St.           M5J 2S1                4
# 67                     199 Bay           M5H 1T1                7
# 68                   6 Coxwell           M4C 3J6                6
# 69                  181 Bay St           M5J 2T3               61
# 70                  161 Bay St           M5J 2S4                2
# 71        52 Wellington St. E.           M5E 1C9               86
# 72                  350 Bay St               M5H               11
# 73                         NaN               M5H                2
# 74     55 Adelaide Street East           M5C 1K6               33
# 75              898 Queen St E           M4M 1J3                4
# 76            1921 Avenue road           M5M 3Z6                8
# 77             2003 Avenue Rd.           M5M 4A5                6
# 78               5051 Yonge St           M2N 5P2                8
# 79           5213 Yonge Street           M2N 5P8                4
# 80                         NaN           M2N 0J4                1
# 81              5229 Yonge St.           M2N 5P8               24
# 82               5165 Yonge St           M2N 5P5               28
# 83               5197 Yonge St           M2N 5P7               27
# 84        41 Spring Garden ave           M2N 3G1                5
# 85             1188 Kennedy Rd           M1P 2L1               29
# 86           1280 Kennedy Road           M1P 2L5               20
# 87         376 Eglinton Ave. W           M5N 1A2                0
# 88            2961 Dundas St W           M6P 1Z2                3
# 89     2907 dundas street west               M6P                3
# 90          1500 Royal York Rd           M9P 3B6                5
# 91                         NaN           M1R 0A1                0
# 92               2685 Yonge St           M4N 2H8                7
# 93         643a Mt Pleasant Rd           M4S 2N3               12
# 94     517 Mount Pleasant Road           M4S 2M2               10
# 95         245 Eglinton Ave. E           M4P 3C2               11
# 96              81 Harbord St.           M5S 1G4               12
# 97               168 Major St.           M5S 1G8               15
# 98              355 Bloor St W               M5S                5
# 99                 18 Jane St.               M6S               16
# 100     2384 Bloor Street West               M6S               10
# 101        3587 Sheppard Ave E           M1T 3K7               11
# 102        3561 Sheppard Ave E           M1T 3K7               12
# 103           322 Spadina Ave.           M5T 2G2               24
# 104          6 Saint Andrew St           M5T 1K6                3
# 105           538 Dundas St. W           M5T 1H3               10
# 106           280 Spadina Ave.           M5T 0A1               11
# 107            707 Dundas St W           M5T 2W6                6
# 108          707 Dundas St. W.           M5T 2W6                9
# 109            358 Bathurst St           M5T 2S6                1
# 110          40 St. Clair West           M6C 1A1               14
# 111        15 St. Clair Ave. W           M4V 1K6                7
# 112            2900 Warden Ave           M1W 2S8                9
# 113       52 Wellington St. E.           M5E 1C9               86
# 114                 181 Bay St           M5J 2T3               61
# 115                 161 Bay St           M5J 2S4                2
# 116    55 Adelaide Street East           M5C 1K6               33
# 117         51B Winchester St.           M4X 1R7               55
# 118             252 Carlton St           M5A 2L3               10
# 119             243 Carlton St           M5A 2L2                5
# 120             235 Carlton St           M5A 2L2                6
# 121                 181 Bay St           M5J 2T3               61
# 122        188 University Ave.           M5H 0A3               32
# 123          111 Richmond St W           M5H 2G4                1
# 124   133 Richmond Street West               M5H                5
# 125                 350 Bay St               M5H               11
# 126             100 Simcoe St.               M5H               27
# 127                 161 Bay St           M5J 2S4                2
# 128           123 Queen St. W.           M5H 3M9               10
# 129             130 King St. W           M5H 3T9                7
# 130          222 Richmond St W           M5V 1W4               72
# 131                        NaN               M5H                2
# 132               650 Yonge St           M4Y 2A6               28
# 133                        NaN           M4Y 1C5                2
# 134               582 Yonge St           M4Y 1Z3               29
# 135           3 Wellesley St W           M4Y 1E7                9
# 136          33 St. Joseph St.           M4Y 1J8               24
# 137             451 Church St.           M4Y 2C5               13
# 138           11 Charles St. W           M4Y 1R4               30
# 139           758 Yonge street           M4Y 2B6                3
# 140                Charles St.           M4Y 1Z8               21
# 141           40 Hayden Street           M4Y 1V8                3
# 142               687 Yonge St           M6H 2C9               17
# 143              459 Church St           M4Y 2C5                9
# 144             640 Church St.           M4W 3T5               30
#
#      Venue Price Tier  Venue Rating  Venue Likes
# 0                   2           7.4           18
# 1                   2           7.6           29
# 2                   2           8.1           32
# 3                   2           7.7            9
# 4                   1           7.7           35
# 5                   4           6.8           12
# 6                   2           8.0          304
# 7                   2           7.9          484
# 8                   2           8.6          382
# 9                <NA>           8.3           60
# 10                  1           7.7           35
# 11                  2           7.3           14
# 12                  2           7.6            7
# 13                  2           6.7           28
# 14                  2           6.8            8
# 15                  2           NaN            2
# 16                  2           6.5           13
# 17                  2           5.8           14
# 18                  1           5.5           14
# 19                  2           NaN            0
# 20                  2           8.6           42
# 21                  2           8.4          218
# 22                  2           7.4           17
# 23                  2           8.4          218
# 24                  2           7.7           13
# 25               <NA>           NaN            0
# 26                  2           7.2           16
# 27                  2           8.1           21
# 28                  3           8.0          160
# 29                  2           6.4            0
# 30                  2           6.2            6
# 31                  2           5.7           14
# 32                  2           6.7            4
# 33                  2           6.2           39
# 34                  1           NaN            0
# 35                  4           8.0           69
# 36                  3           8.3          188
# 37                  2           9.0          686
# 38                  2           7.7           53
# 39                  2           8.0          126
# 40                  3           8.0           84
# 41                  2           7.1            5
# 42                  2           7.1            7
# 43                  2           6.3            5
# 44                  2           6.0           30
# 45                  1           NaN            3
# 46                  2           NaN            2
# 47                  2           NaN            0
# 48                  2           NaN            0
# 49                  2           8.8          142
# 50                  3           8.2          119
# 51                  2           7.5           19
# 52                  2           8.9           71
# 53                  2           8.8          149
# 54                  1           8.3          132
# 55                  2           8.1           28
# 56                  2           8.6           83
# 57                  1           8.3          133
# 58                  1           6.6            7
# 59                  2           NaN            2
# 60                  3           8.0           94
# 61                  2           7.7           13
# 62                  4           8.0           69
# 63                  2           7.6            9
# 64                  2           7.4           17
# 65                  2           7.5           12
# 66                  1           6.7           12
# 67                  2           6.6            6
# 68                  2           7.5            6
# 69                  3           8.0           94
# 70                  2           7.7           13
# 71                  2           8.4          218
# 72                  2           7.4           17
# 73                  2           7.1            7
# 74                  3           7.9           55
# 75                  2           7.5            6
# 76                  2           6.9           16
# 77                  2           6.9            7
# 78               <NA>           8.2           39
# 79                  2           7.0           12
# 80                  2           6.8            6
# 81               <NA>           6.5           53
# 82               <NA>           6.2           60
# 83                  2           6.1           28
# 84                  2           5.6            3
# 85                  2           7.1           14
# 86                  2           6.2           23
# 87                  2           NaN            0
# 88                  2           7.7            7
# 89                  2           6.9            4
# 90                  1           7.3            7
# 91                  2           NaN            1
# 92                  2           6.7            8
# 93                  2           7.3           11
# 94                  2           7.2            7
# 95                  2           7.2           21
# 96                  2           8.6           46
# 97                  2           8.2           24
# 98                  2           7.6           15
# 99                  2           7.3            6
# 100                 2           7.2            4
# 101                 1           7.2           22
# 102                 2           7.0           15
# 103                 1           8.5           43
# 104                 2           8.2            9
# 105                 2           8.0           15
# 106                 1           7.6           35
# 107                 2           8.3            7
# 108                 2           7.9           21
# 109                 2           5.8            7
# 110                 2           7.5            7
# 111                 2           6.1            4
# 112                 1           7.5           18
# 113                 2           8.4          218
# 114                 3           8.0           94
# 115                 2           7.7           13
# 116                 3           7.9           55
# 117                 2           8.7          113
# 118              <NA>           7.9           42
# 119                 2           7.1            6
# 120                 1           6.1            4
# 121                 3           8.0           94
# 122                 4           8.0           69
# 123                 2           7.5           12
# 124                 2           7.6            9
# 125                 2           7.4           17
# 126                 2           7.7           53
# 127                 2           7.7           13
# 128                 2           7.7           22
# 129                 2           7.1            5
# 130                 3           8.3          188
# 131                 2           7.1            7
# 132              <NA>           8.3          114
# 133                 2           7.9           12
# 134                 1           7.7           35
# 135                 2           7.7            9
# 136                 2           8.1           32
# 137                 2           7.7           27
# 138                 2           7.8           59
# 139                 2           7.9            7
# 140                 2           7.4           20
# 141                 2           7.7           13
# 142                 2           7.5           32
# 143                 2           6.6            1
# 144                 2           6.3           22

# %%
# Fix the lat, long of the Neighborhoods
pd.reset_option("max_rows")
fix_lat_long = fsa_df.set_index('PostalCode')[ ['Latitude', 'Longitude'] ]
asian_restaurants = asian_restaurants.join(fix_lat_long, on='Neighborhood')
asian_restaurants = asian_restaurants.drop(columns=[ 'Neighborhood Latitude', 'Neighborhood Longitude'])
asian_restaurants = asian_restaurants.rename(columns={
    'Latitude': 'Neighborhood Latitude',
    'Longitude': 'Neighborhood Longitude'
})
cols = asian_restaurants.columns.to_list()
cols = [cols[0]] + cols[-2:] + cols[1:-2]
asian_restaurants = asian_restaurants[cols]
asian_restaurants
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0            M5A              43.654260              -79.360636
# 1            M6A              43.718518              -79.464763
# 2            M4Y              43.665860              -79.383160
# 3            M4Y              43.665860              -79.383160
# 4            M4Y              43.665860              -79.383160
# ..           ...                    ...                     ...
# 140          M4Y              43.665860              -79.383160
# 141          M4Y              43.665860              -79.383160
# 142          M6H              43.669005              -79.442259
# 143          M4Y              43.665860              -79.383160
# 144          M4W              43.679563              -79.377529
#
#                               Venue                  Venue ID  Venue Latitude  \
# 0                             Izumi  50e88fc6e4b007fcbb57aae8       43.649970
# 1    Lac Vien Vietnamese Restaurant  4ccc5aebee23a14370591ea8       43.721259
# 2                       Tokyo Sushi  4afca145f964a5208e2422e3       43.665885
# 3                      Sushi Garden  4ba6b463f964a520416a39e3       43.664858
# 4                       Tokyo Grill  4ad4c061f964a520abf720e3       43.665085
# ..                              ...                       ...             ...
# 140                   Tokyo Kitchen  4ae787b9f964a52020ac21e3       43.668783
# 141                   Onnki Donburi  59c54d4f2d2fd97564d4cfc8       43.669757
# 142                      Miss Korea  527428a5498e8e23580dbe15       43.668950
# 143                  Kokoni Izakaya  4c531b60a724e21e029e3af4       43.664181
# 144                     Asahi Sushi  4af0b965f964a52094de21e3       43.669874
#
#      Venue Longitude         Venue Category       Venue Address  \
# 0         -79.360153       Asian Restaurant                 NaN
# 1         -79.468472  Vietnamese Restaurant  141 Cartwright Ave
# 2         -79.386977       Sushi Restaurant   33 St. Joseph St.
# 3         -79.384941       Sushi Restaurant    3 Wellesley St W
# 4         -79.384707    Japanese Restaurant        582 Yonge St
# ..               ...                    ...                 ...
# 140       -79.385153    Japanese Restaurant         Charles St.
# 141       -79.384574    Japanese Restaurant    40 Hayden Street
# 142       -79.386165      Korean Restaurant        687 Yonge St
# 143       -79.380258    Japanese Restaurant       459 Church St
# 144       -79.382943       Sushi Restaurant      640 Church St.
#
#     Venue Postal Code  Venue Tip Count  Venue Price Tier  Venue Rating  \
# 0             M5A 3C4                4                 2           7.4
# 1             M6A 2X3               12                 2           7.6
# 2             M4Y 1J8               24                 2           8.1
# 3             M4Y 1E7                9                 2           7.7
# 4             M4Y 1Z3               29                 1           7.7
# ..                ...              ...               ...           ...
# 140           M4Y 1Z8               21                 2           7.4
# 141           M4Y 1V8                3                 2           7.7
# 142           M6H 2C9               17                 2           7.5
# 143           M4Y 2C5                9                 2           6.6
# 144           M4W 3T5               30                 2           6.3
#
#      Venue Likes
# 0             18
# 1             29
# 2             32
# 3              9
# 4             35
# ..           ...
# 140           20
# 141           13
# 142           32
# 143            1
# 144           22
#
# [145 rows x 14 columns]

# %%
# Check for the dupes
asian_restaurants.loc[asian_restaurants.duplicated(subset='Venue ID', keep=False)].sort_values(by='Venue ID')
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 134          M4Y              43.665860              -79.383160
# 4            M4Y              43.665860              -79.383160
# 121          M5J              43.640816              -79.381752
# 114          M5J              43.640816              -79.381752
# 69           M5J              43.640816              -79.381752
# 60           M5J              43.640816              -79.381752
# 126          M5H              43.650571              -79.384568
# 38           M5H              43.650571              -79.384568
# 2            M4Y              43.665860              -79.383160
# 136          M4Y              43.665860              -79.383160
# 41           M5H              43.650571              -79.384568
# 129          M5H              43.650571              -79.384568
# 74           M5C              43.651494              -79.375418
# 116          M5C              43.651494              -79.375418
# 135          M4Y              43.665860              -79.383160
# 3            M4Y              43.665860              -79.383160
# 64           M5H              43.650571              -79.384568
# 22           M5H              43.650571              -79.384568
# 125          M5H              43.650571              -79.384568
# 72           M5H              43.650571              -79.384568
# 62           M5H              43.650571              -79.384568
# 35           M5H              43.650571              -79.384568
# 122          M5H              43.650571              -79.384568
# 63           M5H              43.650571              -79.384568
# 124          M5H              43.650571              -79.384568
# 36           M5V              43.628947              -79.394420
# 130          M5V              43.628947              -79.394420
# 21           M5E              43.644771              -79.373306
# 23           M5E              43.644771              -79.373306
# 113          M5E              43.644771              -79.373306
# 71           M5E              43.644771              -79.373306
# 73           M5H              43.650571              -79.384568
# 131          M5H              43.650571              -79.384568
# 42           M5H              43.650571              -79.384568
# 70           M5J              43.640816              -79.381752
# 24           M5J              43.640816              -79.381752
# 127          M5J              43.640816              -79.381752
# 61           M5J              43.640816              -79.381752
# 115          M5J              43.640816              -79.381752
# 123          M5H              43.650571              -79.384568
# 65           M5H              43.650571              -79.384568
#
#                                 Venue                  Venue ID  \
# 134                       Tokyo Grill  4ad4c061f964a520abf720e3
# 4                         Tokyo Grill  4ad4c061f964a520abf720e3
# 121          Ki Modern Japanese + Bar  4ae73054f964a5203ca921e3
# 114          Ki Modern Japanese + Bar  4ae73054f964a5203ca921e3
# 69           Ki Modern Japanese + Bar  4ae73054f964a5203ca921e3
# 60           Ki Modern Japanese + Bar  4ae73054f964a5203ca921e3
# 126          Fune Japanese Restaurant  4afa1f33f964a520e91622e3
# 38           Fune Japanese Restaurant  4afa1f33f964a520e91622e3
# 2                         Tokyo Sushi  4afca145f964a5208e2422e3
# 136                       Tokyo Sushi  4afca145f964a5208e2422e3
# 41                        Thai Island  4b50d070f964a5206d3327e3
# 129                       Thai Island  4b50d070f964a5206d3327e3
# 74                               NAMI  4b999927f964a5207c8635e3
# 116                              NAMI  4b999927f964a5207c8635e3
# 135                      Sushi Garden  4ba6b463f964a520416a39e3
# 3                        Sushi Garden  4ba6b463f964a520416a39e3
# 64                         Sweet Lulu  4ba90db8f964a5203f073ae3
# 22                         Sweet Lulu  4ba90db8f964a5203f073ae3
# 125                        Sweet Lulu  4ba90db8f964a5203f073ae3
# 72                         Sweet Lulu  4ba90db8f964a5203f073ae3
# 62                 Bosk at Shangri-La  50468014e4b01c18bb731df8
# 35                 Bosk at Shangri-La  50468014e4b01c18bb731df8
# 122                Bosk at Shangri-La  50468014e4b01c18bb731df8
# 63                      Ninki Izakaya  506a3830e4b0677a1f9d8eda
# 124                     Ninki Izakaya  506a3830e4b0677a1f9d8eda
# 36                           JaBistro  509bb871e4b09c7ac93f6642
# 130                          JaBistro  509bb871e4b09c7ac93f6642
# 21                          Sukhothai  50b7c53616485cd9efad60d5
# 23                          Sukhothai  50b7c53616485cd9efad60d5
# 113                         Sukhothai  50b7c53616485cd9efad60d5
# 71                          Sukhothai  50b7c53616485cd9efad60d5
# 73   Ruby Thai (First Canadian Place)  5632426a498e0433cad5aa04
# 131  Ruby Thai (First Canadian Place)  5632426a498e0433cad5aa04
# 42   Ruby Thai (First Canadian Place)  5632426a498e0433cad5aa04
# 70                       Chotto Matte  5a4fdf56772fbc5e9fa73c7f
# 24                       Chotto Matte  5a4fdf56772fbc5e9fa73c7f
# 127                      Chotto Matte  5a4fdf56772fbc5e9fa73c7f
# 61                       Chotto Matte  5a4fdf56772fbc5e9fa73c7f
# 115                      Chotto Matte  5a4fdf56772fbc5e9fa73c7f
# 123                             Tachi  5a6bad222632ec473853718a
# 65                              Tachi  5a6bad222632ec473853718a
#
#      Venue Latitude  Venue Longitude       Venue Category  \
# 134       43.665085       -79.384707  Japanese Restaurant
# 4         43.665085       -79.384707  Japanese Restaurant
# 121       43.647223       -79.379374  Japanese Restaurant
# 114       43.647223       -79.379374  Japanese Restaurant
# 69        43.647223       -79.379374  Japanese Restaurant
# 60        43.647223       -79.379374  Japanese Restaurant
# 126       43.648514       -79.386457  Japanese Restaurant
# 38        43.648514       -79.386457  Japanese Restaurant
# 2         43.665885       -79.386977     Sushi Restaurant
# 136       43.665885       -79.386977     Sushi Restaurant
# 41        43.649146       -79.383798      Thai Restaurant
# 129       43.649146       -79.383798      Thai Restaurant
# 74        43.650853       -79.375887  Japanese Restaurant
# 116       43.650853       -79.375887  Japanese Restaurant
# 135       43.664858       -79.384941     Sushi Restaurant
# 3         43.664858       -79.384941     Sushi Restaurant
# 64        43.650557       -79.381175     Asian Restaurant
# 22        43.650557       -79.381175     Asian Restaurant
# 125       43.650557       -79.381175     Asian Restaurant
# 72        43.650557       -79.381175     Asian Restaurant
# 62        43.649023       -79.385826     Asian Restaurant
# 35        43.649023       -79.385826     Asian Restaurant
# 122       43.649023       -79.385826     Asian Restaurant
# 63        43.650228       -79.384863  Japanese Restaurant
# 124       43.650228       -79.384863  Japanese Restaurant
# 36        43.649687       -79.388090     Sushi Restaurant
# 130       43.649687       -79.388090     Sushi Restaurant
# 21        43.648487       -79.374547      Thai Restaurant
# 23        43.648487       -79.374547      Thai Restaurant
# 113       43.648487       -79.374547      Thai Restaurant
# 71        43.648487       -79.374547      Thai Restaurant
# 73        43.649091       -79.381600      Thai Restaurant
# 131       43.649091       -79.381600      Thai Restaurant
# 42        43.649091       -79.381600      Thai Restaurant
# 70        43.646473       -79.378782  Japanese Restaurant
# 24        43.646473       -79.378782  Japanese Restaurant
# 127       43.646473       -79.378782  Japanese Restaurant
# 61        43.646473       -79.378782  Japanese Restaurant
# 115       43.646473       -79.378782  Japanese Restaurant
# 123       43.650596       -79.383396     Sushi Restaurant
# 65        43.650596       -79.383396     Sushi Restaurant
#
#                 Venue Address Venue Postal Code  Venue Tip Count  \
# 134              582 Yonge St           M4Y 1Z3               29
# 4                582 Yonge St           M4Y 1Z3               29
# 121                181 Bay St           M5J 2T3               61
# 114                181 Bay St           M5J 2T3               61
# 69                 181 Bay St           M5J 2T3               61
# 60                 181 Bay St           M5J 2T3               61
# 126            100 Simcoe St.               M5H               27
# 38             100 Simcoe St.               M5H               27
# 2           33 St. Joseph St.           M4Y 1J8               24
# 136         33 St. Joseph St.           M4Y 1J8               24
# 41             130 King St. W           M5H 3T9                7
# 129            130 King St. W           M5H 3T9                7
# 74    55 Adelaide Street East           M5C 1K6               33
# 116   55 Adelaide Street East           M5C 1K6               33
# 135          3 Wellesley St W           M4Y 1E7                9
# 3            3 Wellesley St W           M4Y 1E7                9
# 64                 350 Bay St               M5H               11
# 22                 350 Bay St               M5H               11
# 125                350 Bay St               M5H               11
# 72                 350 Bay St               M5H               11
# 62        188 University Ave.           M5H 0A3               32
# 35        188 University Ave.           M5H 0A3               32
# 122       188 University Ave.           M5H 0A3               32
# 63   133 Richmond Street West               M5H                5
# 124  133 Richmond Street West               M5H                5
# 36          222 Richmond St W           M5V 1W4               72
# 130         222 Richmond St W           M5V 1W4               72
# 21       52 Wellington St. E.           M5E 1C9               86
# 23       52 Wellington St. E.           M5E 1C9               86
# 113      52 Wellington St. E.           M5E 1C9               86
# 71       52 Wellington St. E.           M5E 1C9               86
# 73                        NaN               M5H                2
# 131                       NaN               M5H                2
# 42                        NaN               M5H                2
# 70                 161 Bay St           M5J 2S4                2
# 24                 161 Bay St           M5J 2S4                2
# 127                161 Bay St           M5J 2S4                2
# 61                 161 Bay St           M5J 2S4                2
# 115                161 Bay St           M5J 2S4                2
# 123         111 Richmond St W           M5H 2G4                1
# 65          111 Richmond St W           M5H 2G4                1
#
#      Venue Price Tier  Venue Rating  Venue Likes
# 134                 1           7.7           35
# 4                   1           7.7           35
# 121                 3           8.0           94
# 114                 3           8.0           94
# 69                  3           8.0           94
# 60                  3           8.0           94
# 126                 2           7.7           53
# 38                  2           7.7           53
# 2                   2           8.1           32
# 136                 2           8.1           32
# 41                  2           7.1            5
# 129                 2           7.1            5
# 74                  3           7.9           55
# 116                 3           7.9           55
# 135                 2           7.7            9
# 3                   2           7.7            9
# 64                  2           7.4           17
# 22                  2           7.4           17
# 125                 2           7.4           17
# 72                  2           7.4           17
# 62                  4           8.0           69
# 35                  4           8.0           69
# 122                 4           8.0           69
# 63                  2           7.6            9
# 124                 2           7.6            9
# 36                  3           8.3          188
# 130                 3           8.3          188
# 21                  2           8.4          218
# 23                  2           8.4          218
# 113                 2           8.4          218
# 71                  2           8.4          218
# 73                  2           7.1            7
# 131                 2           7.1            7
# 42                  2           7.1            7
# 70                  2           7.7           13
# 24                  2           7.7           13
# 127                 2           7.7           13
# 61                  2           7.7           13
# 115                 2           7.7           13
# 123                 2           7.5           12
# 65                  2           7.5           12

# %%
# Final cleaned dataframe
asian_restaurants.drop_duplicates(ignore_index=True, inplace=True)
asian_restaurants
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0            M5A              43.654260              -79.360636
# 1            M6A              43.718518              -79.464763
# 2            M4Y              43.665860              -79.383160
# 3            M4Y              43.665860              -79.383160
# 4            M4Y              43.665860              -79.383160
# ..           ...                    ...                     ...
# 114          M4Y              43.665860              -79.383160
# 115          M4Y              43.665860              -79.383160
# 116          M6H              43.669005              -79.442259
# 117          M4Y              43.665860              -79.383160
# 118          M4W              43.679563              -79.377529
#
#                               Venue                  Venue ID  Venue Latitude  \
# 0                             Izumi  50e88fc6e4b007fcbb57aae8       43.649970
# 1    Lac Vien Vietnamese Restaurant  4ccc5aebee23a14370591ea8       43.721259
# 2                       Tokyo Sushi  4afca145f964a5208e2422e3       43.665885
# 3                      Sushi Garden  4ba6b463f964a520416a39e3       43.664858
# 4                       Tokyo Grill  4ad4c061f964a520abf720e3       43.665085
# ..                              ...                       ...             ...
# 114                   Tokyo Kitchen  4ae787b9f964a52020ac21e3       43.668783
# 115                   Onnki Donburi  59c54d4f2d2fd97564d4cfc8       43.669757
# 116                      Miss Korea  527428a5498e8e23580dbe15       43.668950
# 117                  Kokoni Izakaya  4c531b60a724e21e029e3af4       43.664181
# 118                     Asahi Sushi  4af0b965f964a52094de21e3       43.669874
#
#      Venue Longitude         Venue Category       Venue Address  \
# 0         -79.360153       Asian Restaurant                 NaN
# 1         -79.468472  Vietnamese Restaurant  141 Cartwright Ave
# 2         -79.386977       Sushi Restaurant   33 St. Joseph St.
# 3         -79.384941       Sushi Restaurant    3 Wellesley St W
# 4         -79.384707    Japanese Restaurant        582 Yonge St
# ..               ...                    ...                 ...
# 114       -79.385153    Japanese Restaurant         Charles St.
# 115       -79.384574    Japanese Restaurant    40 Hayden Street
# 116       -79.386165      Korean Restaurant        687 Yonge St
# 117       -79.380258    Japanese Restaurant       459 Church St
# 118       -79.382943       Sushi Restaurant      640 Church St.
#
#     Venue Postal Code  Venue Tip Count  Venue Price Tier  Venue Rating  \
# 0             M5A 3C4                4                 2           7.4
# 1             M6A 2X3               12                 2           7.6
# 2             M4Y 1J8               24                 2           8.1
# 3             M4Y 1E7                9                 2           7.7
# 4             M4Y 1Z3               29                 1           7.7
# ..                ...              ...               ...           ...
# 114           M4Y 1Z8               21                 2           7.4
# 115           M4Y 1V8                3                 2           7.7
# 116           M6H 2C9               17                 2           7.5
# 117           M4Y 2C5                9                 2           6.6
# 118           M4W 3T5               30                 2           6.3
#
#      Venue Likes
# 0             18
# 1             29
# 2             32
# 3              9
# 4             35
# ..           ...
# 114           20
# 115           13
# 116           32
# 117            1
# 118           22
#
# [119 rows x 14 columns]

# %%
# Save the data to file
with open('asian_restaurants.pkl', 'wb') as f:
        pickle.dump(asian_restaurants, f, pickle.HIGHEST_PROTOCOL)
